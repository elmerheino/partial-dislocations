# %%
import pickle

# %%
path = "../results/2025-12-23-pinned-field/partial/l-128-d-32/shape_data/extra_info_dump-l-128-s-1-d0-32.pickle"
with open(path, "rb") as fp:
    data = pickle.load(fp)

# %%
print(f"len(data) = {len(data)}")
print(f"data[0].keys() = {data[0].keys()}")
# Out:
# len(data) = 15
# data[0].keys() = dict_keys(['tau_ext', 'converged', 'shapes', 'deltaR'])

# %%
import matplotlib.pyplot as plt

tau_ext = data[12]['tau_ext']
converged = data[12]['converged']

plt.figure(figsize=(8, 4))
plt.plot(tau_ext, converged, marker='o', linestyle='-', label='Converged')
plt.xlabel('tau_ext')
plt.ylabel('Converged (binary)')
plt.title('Convergence vs tau_ext')
plt.grid(True)
plt.show()

# %%
path = "../results/2025-10-27-uncorrelated/partial/l-64-d-4/psd_data/psd_data_seed-21_deltaR--0.4285714285714288.pickle"
with open(path, "rb") as fp:
    data = pickle.load(fp)
# Out:
# array([1.30167525e+15, 1.17731230e+02, 2.88750837e+01, 3.65364205e+00,
#        2.45693178e+00, 4.37282401e-01, 1.27771426e+00, 2.06230795e+00,
#        1.78706863e+00, 7.93809254e-01, 1.14425203e-01, 9.83760210e-01,
#        8.18835216e-02, 9.36735774e-02, 4.40776219e-02, 2.24196159e-02,
#        1.46911139e-02, 7.12686984e-02, 6.12558804e-02, 7.76960990e-03,
#        1.47891015e-02, 3.16125248e-02, 7.02110595e-03, 8.26996646e-02,
#        1.12613233e-02, 5.71696581e-03, 3.32848612e-03, 2.11499674e-03,
#        3.55581587e-03, 1.51360440e-03, 3.58398190e-03, 7.91463033e-03,
#        6.43556441e-03, 7.91463033e-03, 3.58398190e-03, 1.51360440e-03,
#        3.55581587e-03, 2.11499674e-03, 3.32848612e-03, 5.71696581e-03,
#        1.12613233e-02, 8.26996646e-02, 7.02110595e-03, 3.16125248e-02,
#        1.47891015e-02, 7.76960990e-03, 6.12558804e-02, 7.12686984e-02,
#        1.46911139e-02, 2.24196159e-02, 4.40776219e-02, 9.36735774e-02,
# ...
